# %% [markdown]
# *What will be the output of the code*

# %%
A,B,C,D = 9.2,2.0,4,21
print((A/4),(A//4))
print(B**C)
print(D//B)
print(A%C)
# Out:
# 2.3 2.0
# 16.0
# 10.0
# 1.1999999999999993

# %% [markdown]
# **Print the area of the circle where radius is 3.75 metres**

# %%
Radius = 3.75
Area = 3.14 * Radius**2
print(Area,'sq.metre')
# Out:
# 44.15625 sq.metre

# %% [markdown]
# Guess the output

# %%
x,z=5,10
y=x+3
x=x-1
x=x+z
print('x:',x,'y:',y,'z:',z)
# Out:
# x: 14 y: 8 z: 10

# %% [markdown]
# Guess the output

# %%
print(14//4,14%4,14/4)
# Out:
# 3 2 3.5
